# %% [markdown]
# This dataset is originally from the National Institute of Diabetes and Digestive and Kidney
# Diseases. The objective of the dataset is to diagnostically predict whether a patient has diabetes,
# based on certain diagnostic measurements included in the dataset. Several constraints were placed
# on the selection of these instances from a larger database. In particular, all patients here are females
# at least 21 years old of Pima Indian heritage.2
# From the data set in the (.csv) File We can find several variables, some of them are independent
# (several medical predictor variables) and only one target dependent variable (Outcome).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
from sklearn import linear_model
import statsmodels.api as sm
import pandas as pd

# %%
df_diabetes = pd.read_csv("/content/drive/Shareddrives/Applied Statistics Project/data/diabetes.csv")

# %%
len(df_diabetes)
# Out:
# 768

# %%
df_diabetes.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
X = df_diabetes[['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age']]
y = df_diabetes[['Outcome']]

# %%
regr = linear_model.LinearRegression()
regr.fit(X,y)
# Out:
# LinearRegression()

# %%
print('Intercept: ',regr.intercept_)
print('Coefficient: ',regr.coef_)
# Out:
# Intercept:  [-0.85389427]
# Coefficient:  [[ 0.02059187  0.00592027 -0.00233188  0.00015452 -0.00018053  0.01324403
#    0.14723744  0.00262139]]

# %%
cccc/
# Out:
#   File "<ipython-input-10-f1c74b365299>", line 1
#     cccc/
#          ^
# SyntaxError: invalid syntax
